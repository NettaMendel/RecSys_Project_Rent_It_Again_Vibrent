# %% [markdown]
# # Get Best Hyperparameters
# This notebook print the best hyperparameters for each model.

# %%
from google.colab import drive
drive.mount('/content/drive')
path='/content/drive/MyDrive/RecSys_206894495'
# %run /content/drive/MyDrive/RecSys_206894495/models/evaluate_models.ipynb
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#import
#warning
import warnings
warnings.filterwarnings('ignore')

#general
import pandas as pd
import numpy as np
from itertools import product
import json

# %%
print('ALS')
print(retrieve_best_model_params_from_file(path + "/models/val.json", 'ALS', n=10))
print('BPR')
print(retrieve_best_model_params_from_file(path + "/models/val.json", 'BPR', n=10))
print('LMF')
print(retrieve_best_model_params_from_file(path + "/models/val.json", 'LMF', n=10))
print('NN')
print(retrieve_best_model_params_from_file(path + "/models/val.json", 'NN', n=10))
print('BM25')
print(retrieve_best_model_params_from_file(path + "/models/val.json", 'BM25', n=10))
print('KNN_rating')
print('outfits')
print(retrieve_best_model_params_from_file_outfit('KNN_rating', n=10))
print('group')
print(retrieve_best_model_params_from_file_group('KNN_rating', n=10))
print('SVD_rating')
print('outfits')
print(retrieve_best_model_params_from_file_outfit('SVD_rating', n=10))
print('group')
print( retrieve_best_model_params_from_file_group('SVD_rating', n=10))
print('SVD++_rating')
print('outfits')
print(retrieve_best_model_params_from_file_outfit('SVDpp_rating', n=10))
print('group')
print(retrieve_best_model_params_from_file_group('SVDpp_rating', n=10))
print('NMF_rating')
print('outfits')
print(retrieve_best_model_params_from_file_outfit('NMF_rating', n=10))
print('group')
print(retrieve_best_model_params_from_file_group('NMF_rating', n=10))
# Out:
# ALS
# {'test_factors': 48, 'test_regularization': 0.005}
# BPR
# {'test_factors': 216, 'test_regularization': 0.02, 'test_learning_rate': 0.005}
# LMF
# {'test_factors': 64, 'test_regularization': 0.01, 'test_learning_rate': 0.005}
# NN
# {'k': 10}
# BM25
# {'k': 10, 'k1': 100, 'b': 0.9}
# KNN_rating
# outfits
# {'k': 5, 'name': 'cosine', 'min_support': 1, 'user_based': False}
# group
# {'k': 5, 'name': 'cosine', 'min_support': 1, 'user_based': False}
# SVD_rating
# outfits
# {'n_factors': 50, 'n_epochs': 10, 'lr_all': 0.01, 'reg_all': 0.05}
# group
# {'n_factors': 50, 'n_epochs': 10, 'lr_all': 0.01, 'reg_all': 0.05}
# SVD++_rating
# outfits
# {'n_factors': 50, 'n_epochs': 10, 'lr_all': 0.01, 'reg_all': 0.05}
# group
# {'n_factors': 50, 'n_epochs': 10, 'lr_all': 0.01, 'reg_all': 0.05}
# NMF_rating
# outfits
# {'n_factors': 10, 'n_epochs': 50, 'reg_pu': 0.06, 'reg_qi': 0.06}
# group
# {'n_factors': 10, 'n_epochs': 50, 'reg_pu': 0.06, 'reg_qi': 0.06}
